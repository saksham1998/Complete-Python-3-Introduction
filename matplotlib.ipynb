# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
x = np.linspace(0,5,11)
y = x**2

# %% [raw]
# #Now their are two methods for plotting
# 1. Functional
# 2. OOP

# %%
#Functional

plt.plot(x,y)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('My Title')
# Out:
# Text(0.5,1,'My Title')

# %%
#Making multiple plots on same set
plt.subplot(1,3,1)
plt.plot(x,y)

plt.subplot(1,3,2)
plt.plot(y,x)

plt.subplot(1,3,3)
plt.plot(y**2,x**3)

# %%
#OOP Method

fig = plt.figure()
axes = fig.add_axes([0.1,0.2,0.9,0.9]) 
axes2 = fig.add_axes([0.2,0.7,0.5,0.2])
#axes.plot(x,y)

axes.plot(x,y)
axes.set_title('Title 1')

axes2.plot(y,x)
axes.set_title('Title 2')
# Out:
# Text(0.5,1,'Title 2')

# %%
# How to create subplots in OOP method:

fig,axes = plt.subplots(nrows=1,ncols=3)

plt.tight_layout()#for better layout

axes[0].plot(x,y)
axes[0].set_title('Title 1')


axes[1].plot(y,x)
axes[1].set_title('Title 2')

axes[2].plot(y**2,x**3)
axes[2].set_title('Title 3')
# Out:
# Text(0.5,1,'Title 3')

# %% [markdown]
# # Figures and DPI

# %%
fig = plt.figure(figsize=(8,2),dpi=100)#figsize is size of the figure in inches .DPI is Dots per Inch
ax = fig.add_axes([.1,.1,.9,.9])
ax.plot(x,y,'r')

# %%
#or by subplot example

fig,axes = plt.subplots(figsize=(10,3),dpi=100)
axes.plot(y,x,'b')

# %%
fig,axes = plt.subplots(nrows=1,ncols=3,figsize=(8,3))
a=x
b=y
for each in axes:
    each.plot(a,b)
    a,b = a**3,b**3   
plt.tight_layout()

# %%
fig

# %%
# If you want to save a figure onto your computer

fig.savefig('myfistfig.png')

# %%
#Ploting two plots on same figure


fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.9,0.9])
axes.plot(x,x**2,'r',label='Square')
axes.plot(x,x**3,'y',label='Cube')

axes.legend()

# %% [markdown]
# # Figure Apperances

# %%
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
axes.plot(x,y,color='purple',linewidth=3,alpha=0.7,linestyle='-',marker='*',markersize=17)

#linewidth(lw) : how bold the line would be
#alpha : how transparent the line would be.Note, the values of alpha must be between 0 to 1.
#linestyle(ls) : different linestyles
#marker : mark the values on x-y plot
#markersize(ms) : configures the size of marker

# %%
#Example 2:
fig = plt.figure(figsize=(8,2))
axes = fig.add_axes([0,0,1,1])
axes.plot(y,x,'black',lw=1,alpha=0.6,ls='steps',marker='o',ms=20)
